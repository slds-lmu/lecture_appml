# %%
import numpy as np
import pandas as pd

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import StratifiedKFold

# Set seed for reproducibility
rng = np.random.default_rng(7832)

# Load the German Credit dataset from OpenML
# Note: "credit-g" is the identifier used in OpenML for the German Credit dataset.
german = fetch_openml("credit-g", version=1, as_frame=True)
df = german.frame

# Assume the target variable is named 'credit_risk'.
# If it is not present, you might need to adjust the target column name.
target_var = "credit_risk"
if target_var not in df.columns:
    # Alternative fallback (common alternative in this dataset)
    raise ValueError(f"Target variable '{target_var}' not found in the dataset. "
                     "Please select another column name for the target variable.")

# Display stratification information: count and row ids for each group in the target variable.
strata = df.groupby(target_var).apply(
    lambda group: {"N": len(group), "row_id": ", ".join(map(str, group.index))})
print(f"Strata information:\n{strata}\n")

# Create a 3-fold stratified cross validation
cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=7832)

# Separate features and target
X = df.drop(columns=[target_var])
y = df[target_var]

# Assign a fold number to each observation (based on the test indices in each split)
fold_assignments = np.zeros(len(df), dtype=int)
for fold, (_, test_idx) in enumerate(cv.split(X, y), start=1):
    fold_assignments[test_idx] = fold

# Create a DataFrame to display the resampling instance: each row with its corresponding fold number.
cv_instance = pd.DataFrame({
    "row_id": df.index,
    "fold": fold_assignments
}).sort_values(by=['fold', 'row_id'])

print(f"Resampling instance:\n{cv_instance}")
# Out:
# Strata information:
# class
# bad     {'N': 300, 'row_id': '1, 4, 9, 10, 11, 13, 15,...
# good    {'N': 700, 'row_id': '0, 2, 3, 5, 6, 7, 8, 12,...
# dtype: object
#
# Resampling instance:
#      row_id  fold
# 2         2     1
# 6         6     1
# 10       10     1
# 11       11     1
# 13       13     1
# ..      ...   ...
# 980     980     3
# 983     983     3
# 991     991     3
# 997     997     3
# 998     998     3
#
# [1000 rows x 2 columns]

# %%
# Merge the resampling instance with the original data
# Reset the index to create a 'row_id' column that aligns with cv_instance.
df_reset = df.reset_index().rename(columns={'index': 'row_id'})
dt = pd.merge(cv_instance, df_reset, on="row_id")

# Compute the ratio for each fold: ratio = count("bad") / count("good")
fold_ratios = dt.groupby("fold")[target_var].apply(
    lambda x: (x == "bad").sum() / (x == "good").sum()
).reset_index(name="class_ratio")

print("Class ratio within each fold:")
for _, row in fold_ratios.iterrows():
    print(f"Fold {int(row['fold'])}: {row['class_ratio']:.7f}")

# Compute the overall class ratio for sanity check
overall_ratio = (df[target_var] == "bad").sum() / (df[target_var] == "good").sum()
print(f"\nOverall class ratio: {overall_ratio:.7f}")
# Out:
# Class ratio within each fold:
# Fold 1: 0.4273504
# Fold 2: 0.4291845
# Fold 3: 0.4291845
#
# Overall class ratio: 0.4285714

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import GroupKFold

# Load the breast cancer dataset from scikit-learn
data_bc = load_breast_cancer(as_frame=True)
df_bc = data_bc.frame

# Note: In the sklearn version of "breast cancer" dataset, there is no ID column, while the "mlbench" in R code has.
# TODO: @matthias, is there any other option for loading the breast cancer dataset with an ID column?

# We simulate a grouping variable 'Id' by assigning each observation a patient id between 1 and 100.
num_patients = 100
df_bc["Id"] = rng.choice(np.arange(1, num_patients + 1), size=len(df_bc))

# 2.1 Count groups: Count how many patient ids appear more than once.
id_counts = df_bc["Id"].value_counts()
num_multiple = (id_counts > 1).sum()
print(f"Number of Ids with more than one observation: {num_multiple}")

# 2.2 & 2.3 Block resampling: set up 5-fold CV ensuring observations with the same Id remain together.
gkf = GroupKFold(n_splits=5)

# Separate features and target.
# Note: The target column is "target" in this dataset.
X_bc = df_bc.drop(columns=["target"])
y_bc = df_bc["target"]

# Create a mapping from each group (Id) to a fold number.
fold_assignments = pd.DataFrame(columns=["Id", "fold"])
for fold, (train_idx, test_idx) in enumerate(gkf.split(X_bc, y_bc, groups=df_bc["Id"]), start=1):
    unique_ids = df_bc.iloc[test_idx]["Id"].unique()
    temp_df = pd.DataFrame({"Id": unique_ids, "fold": fold})
    fold_assignments = pd.concat([fold_assignments, temp_df], ignore_index=True)
fold_assignments = fold_assignments.sort_values(by="Id").reset_index(drop=True)
print("Block resampling instance (group to fold mapping):")
print(fold_assignments)

# 2.4 Sanity check:
# Merge the original data with the fold assignments by 'Id'
dt = pd.merge(df_bc, fold_assignments, on="Id", how="left")
# Count how many unique folds each Id appears in.
id_fold_counts = dt.groupby("Id")["fold"].nunique()
ids_in_multiple_folds = id_fold_counts[id_fold_counts > 1]

if ids_in_multiple_folds.empty:
    print("Sanity check passed: Each Id appears in exactly one fold.")
else:
    print("Sanity check failed: Some Ids appear in more than one fold:")
    print(ids_in_multiple_folds)
# Out:
# Number of Ids with more than one observation: 99
# Block resampling instance (group to fold mapping):
#      Id fold
# 0     1    5
# 1     2    3
# 2     3    1
# 3     4    5
# 4     5    1
# ..  ...  ...
# 94   96    2
# 95   97    4
# 96   98    4
# 97   99    3
# 98  100    5
#
# [99 rows x 2 columns]
# Sanity check passed: Each Id appears in exactly one fold.

# %%
from numpy.typing import ArrayLike


def threshold_accuracy_score(y_true: ArrayLike, y_pred: ArrayLike) -> float:
    """
    Compute the threshold accuracy score for regression.

    For each observation, if the absolute difference between y_true and y_pred
    is less than the sample standard deviation of y_true, the prediction is
    considered accurate (scored as 1), otherwise 0. The final score is the mean
    of these indicators.

    Parameters
    ----------
    y_true : array-like of shape (n_samples,)
        True target values.
    y_pred : array-like of shape (n_samples,)
        Predicted target values.

    Returns
    -------
    score : float
        The threshold accuracy score, a value between 0 and 1.
    """
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    std_y = np.std(y_true, ddof=1)

    # If the standard deviation is 0 (all values are identical),
    # define accuracy as the fraction of perfect predictions.
    if std_y == 0:
        return np.mean(y_true == y_pred)

    # Compute the indicator: 1 if the prediction is within std_y, else 0.
    indicator = np.abs(y_true - y_pred) < std_y
    return np.mean(indicator)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import statsmodels.api as sm


def max_mse_mae_score(y_true: ArrayLike, y_pred: ArrayLike) -> float:
    """
    Compute the custom risk measure defined as the average of the maximum
    between the squared error and absolute error for each observation.

    Parameters
    ----------
    y_true : array-like of shape (n_samples,)
        True target values.
    y_pred : array-like of shape (n_samples,)
        Predicted target values.

    Returns
    -------
    score : float
        The custom risk measure.
    """
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    squared_error = (y_true - y_pred) ** 2
    absolute_error = np.abs(y_true - y_pred)
    loss = np.maximum(squared_error, absolute_error)
    return np.mean(loss)

# 3.2 Evaluate a custom measure on the mtcars dataset.
# Load the mtcars dataset from statsmodels (similar to R's mtcars)
data_mtcars = sm.datasets.get_rdataset("mtcars", "datasets")
df_mtcars = data_mtcars.data

# For this example, we treat 'mpg' (miles per gallon) as the target variable.
X = df_mtcars.drop(columns=["mpg"])
y = df_mtcars["mpg"]

# Partition the dataset (using a simple train/test split)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=7832)

# Train a regression model (using RandomForestRegressor to mimic 'ranger')
model = RandomForestRegressor(random_state=7832)
model.fit(X_train, y_train)

# Generate predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the predictions with the custom risk measure
score_value = max_mse_mae_score(y_test, y_pred)
print(f"Custom max MSE-MAE score: {score_value:.5f}")
# Out:
# Custom max MSE-MAE score: 4.76320
